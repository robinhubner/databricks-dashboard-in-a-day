# %%
from databricks.sdk import WorkspaceClient
import yaml

data = yaml.safe_load(open("databricks.yml").read())
data["targets"]["dev"]["workspace"]["host"] = WorkspaceClient().config.host
open("databricks.yml", "w").write(yaml.safe_dump(data, sort_keys=False))

# %%
def setup(catalog: str = "sunny_bay"):
    spark.sql(f"CREATE CATALOG IF NOT EXISTS `{catalog}`")
    spark.sql(f"CREATE SCHEMA IF NOT EXISTS `{catalog}`.bronze")
    spark.sql(f"CREATE SCHEMA IF NOT EXISTS `{catalog}`.silver")
    spark.sql(f"CREATE SCHEMA IF NOT EXISTS `{catalog}`.gold")
    spark.sql(f"CREATE VOLUME IF NOT EXISTS `{catalog}`.bronze.raw")

# %%
setup()
